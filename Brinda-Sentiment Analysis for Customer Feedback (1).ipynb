# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import nltk

# %%
train_df=pd.read_csv(r"E:\Naan Mudhalvan\Dataset\sentiment_analysis.csv")
train_df
# Out:
#      Year  Month  Day Time of Tweet  \
# 0    2018      8   18       morning
# 1    2018      8   18          noon
# 2    2017      8   18         night
# 3    2022      6    8       morning
# 4    2022      6    8          noon
# ..    ...    ...  ...           ...
# 494  2015     10   18         night
# 495  2021      2   25       morning
# 496  2022      5   30          noon
# 497  2018      8   10         night
# 498  2019      3   25       morning
#
#                                                                                      text  \
# 0                                                   What a great day!!! Looks like dream.
# 1                                          I feel sorry, I miss you here in the sea beach
# 2                                                                          Don't angry me
# 3    We attend in the class just for listening teachers reading on slide. Just Nonsence
# ...

# %%
pd.set_option('max_colwidth',800)

# %%
# Positive sentiment
train_df.head()
# Out:
#    Year  Month  Day Time of Tweet  \
# 0  2018      8   18       morning
# 1  2018      8   18          noon
# 2  2017      8   18         night
# 3  2022      6    8       morning
# 4  2022      6    8          noon
#
#                                                                                    text  \
# 0                                                 What a great day!!! Looks like dream.
# 1                                        I feel sorry, I miss you here in the sea beach
# 2                                                                        Don't angry me
# 3  We attend in the class just for listening teachers reading on slide. Just Nonsence
# 4                                                     Those who want to go, let them go
#
#   sentiment     Platform
# 0  positive    Twitter
# 1  positive    Facebook
# 2  negative     Facebook
# 3  negative    Facebook
# 4  negative   Instagram

# %%
# Negative sentiment
train_df.tail()
# Out:
#      Year  Month  Day Time of Tweet  \
# 494  2015     10   18         night
# 495  2021      2   25       morning
# 496  2022      5   30          noon
# 497  2018      8   10         night
# 498  2019      3   25       morning
#
#                                                                   text  \
# 494    According to , a quarter of families under six live in poverty.
# 495                      the plan to not spend money is not going well
# 496                    uploading all my bamboozle pictures of facebook
# 497   congratulations ! you guys finish a month early than we do. booo
# 498            actually, I wish I was back in Tahoe.  I miss it there.
#
#     sentiment     Platform
# 494  negative     Twitter
# 495  negative   Instagram
# 496   neutral    Facebook
# 497  positive     Twitter
# 498  negative   Instagram

# %%
# Visualisation
ax=sns.countplot(train_df['sentiment'])
# annotate
for i in ax.patches:
    ax.annotate(i.get_height(),(i.get_x()+0.1,(i.get_height()+80)))
